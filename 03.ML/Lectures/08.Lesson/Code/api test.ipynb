# %%
# !pip install fastapi
# !pip install uvicorn[standard]
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.7/dist-packages (0.68.1)
# Requirement already satisfied: starlette==0.14.2 in /usr/local/lib/python3.7/dist-packages (from fastapi) (0.14.2)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from fastapi) (1.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->fastapi) (3.7.4.3)
# Collecting uvicorn[standard]
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.0 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Collecting h11>=0.8
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.5 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from uvicorn[standard]) (3.7.4.3)
# Collecting PyYAML>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 36.5 MB/s
# Collecting httptools==0.2.*
#   Downloading httptools-0.2.0-cp37-cp37m-manylinux1_x86_64.whl (344 kB)
#      |████████████████████████████████| 344 kB 58.0 MB/s
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.16.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 25.5 MB/s
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-0.19.0-py2.py3-none-any.whl (17 kB)
# Collecting websockets>=9.1
#   Downloading websockets-10.0-cp37-cp37m-manylinux2010_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 65.2 MB/s
# Collecting watchgod>=0.6
#   Downloading watchgod-0.7-py3-none-any.whl (11 kB)
# Installing collected packages: h11, asgiref, websockets, watchgod, uvloop, uvicorn, PyYAML, python-dotenv, httptools
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.4.1 asgiref-3.4.1 h11-0.12.0 httptools-0.2.0 python-dotenv-0.19.0 uvicorn-0.15.0 uvloop-0.16.0 watchgod-0.7 websockets-10.0

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.shape, X_test.shape
# Out:
# ((112, 4), (38, 4))

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

clf = OneVsRestClassifier(SVC()).fit(X_train, y_train)
preds = clf.predict(X_test)

print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.85      1.00      0.92        11
#            2       1.00      0.88      0.93        16
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.96      0.95        38
# weighted avg       0.96      0.95      0.95        38

# %%
# %%writefile main.py
from fastapi import FastAPI
from fastapi.encoders import jsonable_encoder

app = FastAPI()

@app.get("/predictions/{data}")
def update_item(data: str):
    data = jsonable_encoder(data)
    print(type(data), data)
# Out:
# Overwriting main.py

# %%
# !uvicorn main:app --reload
# Out:
# INFO:     Will watch for changes in these directories: ['/content']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [369] using watchgod
# INFO:     Started server process [371]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Shutting down
# INFO:     Finished server process [371]
# INFO:     ASGI 'lifespan' protocol appears unsupported.
# INFO:     Stopping reloader process [369]

# %%
import requests

res = requests.get('http://127.0.0.1:8000/predictions/{"hello":"word"}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d84611a9ca39> in <module>()
#       1 import requests
#       2
# ----> 3 res = requesets.get('http://127.0.0.1:8000/predictions/{"hello":"word"}')
#
# NameError: name 'requesets' is not defined
