# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import ComplementNB, MultinomialNB, BernoulliNB, CategoricalNB, GaussianNB

# %% [markdown]
# # 1.Наивный байесовский классификатор

# %% [markdown]
# *   Теорема позволяет найти вероятность того, что именно эта причина привела к наблюдаемому событию

# %% [markdown]
# <h1 align="center"> $ P(A|B) = \frac{ P(B|A)P(A) }{ P(B) } $ </h1>

# %% [markdown]
# * $ P(A|B) $ — вероятность того, что событие $А$ истинно, если событие $B$ истинно
# * $ P(B|A) $ — вероятность того, что событие $B$ истинно, если событие $A$ истинно
# * $ P(A) $ — вероятность того, что событие $А$ истинно
# * $ P(B) $ — вероятность того, что событие $B$ истинно
#
# ----

# %% [markdown]
# #### Подготовка данных

# %%
from keras.datasets import imdb
import keras

(x_train, y_train), (x_test, y_test) = imdb.load_data(path="imdb.npz",
                                                      num_words=None,
                                                      skip_top=0,
                                                      maxlen=None,
                                                      seed=113,
                                                      start_char=1,
                                                      oov_char=2,
                                                      index_from=3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
x_train
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
#        list([1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 10156, 4, 1153, 9, 194, 775, 7, 8255, 11596, 349, 2637, 148, 605, 15358, 8003, 15, 123, 125, 68, 23141, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 36893, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 25249, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 46151, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]),
#        list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 44076, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 51428, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113]),
#        ...,
#        list([1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 86527, 45, 2174, 84, 8322, 4007, 21, 4, 912, 84, 14532, 325, 725, 134, 15271, 1715, 84, 5, 36, 28, 57, 1099, 21, 8, 140, 8, 703, 5, 11656, 84, 56, 18, 1644, 14, 9, 31, 7, 4, 9406, 1209, 2295, 26094, 1008, 18, 6, 20, 207, 110, 563, 12, 8, 2901, 17793, 8, 97, 6, 20, 53, 4767, 74, 4, 460, 364, 1273, 29, 270, 11, 960, 108, 45, 40, 29, 2961, 395, 11, 6, 4065, 500, 7, 14492, 89, 364, 70, 29, 140, 4, 64, 4780, 11, 4, 2678, 26, 178, 4, 529, 443, 17793, 5, 27, 710, 117, 74936, 8123, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 1242, 1209, 10, 10, 288, 2260, 1702, 34, 2901, 17793, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2766, 234, 1119, 1574, 7, 496, 4, 139, 929, 2901, 17793, 7750, 5, 4241, 18, 4, 8497, 13164, 250, 11, 1818, 7561, 4, 4217, 5408, 747, 1115, 372, 1890, 1006, 541, 9303, 7, 4, 59, 11027, 4, 3586, 22459]),
#        list([1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 4120, 2959, 45, 58, 1466, 13, 197, 12, 16, 43, 23, 21469, 5, 62, 30, 145, 402, 11, 4131, 51, 575, 32, 61, 369, 71, 66, 770, 12, 1054, 75, 100, 2198, 8, 4, 105, 37, 69, 147, 712, 75, 3543, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 1814, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 40691, 40, 319, 5872, 112, 6700, 11, 4803, 121, 25, 70, 3468, 4, 719, 3798, 13, 18, 31, 62, 40, 8, 7200, 4, 29455, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 11418, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 21213, 12, 38, 84, 80, 124, 12, 9, 23]),
#        list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 12815, 270, 14437, 5, 16923, 12255, 732, 2098, 101, 405, 39, 14, 1034, 4, 1310, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 4039, 9245, 9, 24, 6, 78, 1099, 17, 2345, 16553, 21, 27, 9685, 6139, 5, 29043, 1603, 92, 1183, 4, 1310, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 6789, 85010, 9, 6, 66, 78, 1099, 4, 631, 1191, 5, 2642, 272, 191, 1070, 6, 7585, 8, 2197, 70907, 10755, 544, 5, 383, 1271, 848, 1468, 12183, 497, 16876, 8, 1597, 8778, 19280, 21, 60, 27, 239, 9, 43, 8368, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 1791, 72, 7, 51, 6, 1739, 22, 4, 204, 131, 9])],
#       dtype=object)

# %%
y_train
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
def decode_review(sample):
    NUM_WORDS=None
    INDEX_FROM=3   # откуда индексирем

    train,test = keras.datasets.imdb.load_data(num_words=NUM_WORDS, index_from=INDEX_FROM)

    word_to_id = keras.datasets.imdb.get_word_index()
    word_to_id = {k:(v+INDEX_FROM) for k,v in word_to_id.items()}
    word_to_id["<PAD>"] = 0
    word_to_id["<START>"] = 1
    word_to_id["<UNK>"] = 2
    word_to_id["<UNUSED>"] = 3

    id_to_word = {value:key for key,value in word_to_id.items()}

    return ' '.join(id_to_word[id] for id in sample)

# %%
print(decode_review(x_train[0]))
print(y_train[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert redford's is an amazing actor and now the same being director norman's father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for retail and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also congratulations to the two little boy's that played the part's of norman and paul they were just brilliant children are often left out of the praising list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all
# 1

# %%
print(decode_review(x_train[20]))
print(y_train[20])
# Out:
# <START> shown in australia as 'hydrosphere' this incredibly bad movie is so bad that you become hypnotised and have to watch it to the end just to see if it could get any worse and it does the storyline is so predictable it seems written by a high school dramatics class the sets are pathetic but marginally better than the miniatures and the acting is wooden br br the infant 'muppet' seems to have been stolen from the props cupboard of 'total recall' there didn't seem to be a single original idea in the whole movie br br i found this movie to be so bad that i laughed most of the way through br br malcolm mcdowell should hang his head in shame he obviously needed the money
# 0

# %% [markdown]
# ----

# %% [markdown]
# #### Создание алгоритма и обучение

# %% [markdown]
# collections.defaultdict ничем не отличается от обычного словаря за исключением того, что по умолчанию всегда вызывается функция, возвращающая значение:

# %%
import collections

defdict = collections.defaultdict(list)
print(defdict)

for i in range(5):
    defdict[i] = i

print(defdict)
# Out:
# defaultdict(<class 'list'>, {})
# defaultdict(<class 'list'>, {0: 0, 1: 1, 2: 2, 3: 3, 4: 4})

# %% [markdown]
# Пусть у нас есть строка текста $O$. Кроме того, имеются классы $С$, к одному из которых мы должны отнести строку. Нам необходимо найти такой класс с, при котором его вероятность для данной строки была бы максимальна. Найдем этот класс как
#
# <h4 align="center"> $ С = argmax_c P(C|O) $ </h4>
#
#
# $argmax_x f(x)$ есть значение $x$, при котором $f(x)$ максимальна

# %% [markdown]
# Т.к. получить $P(C|O)$ сложно легче вычислить косвенные вероятности используя теорему Байеса:
#
# <h4 align="center"> $ P(C|O) = \frac{ P(O|C)P(C) }{ P(O) } $ </h4>

# %% [markdown]
# Так как мы ищем максимум от функции, то знаменатель нас не интересует (он в данном случае константа). Кроме того, нужно взглянуть на строку O. Обычно, нет смысла работать со всей строкой. Намного эффективней выделить из нее определенные признаки (features). Таким образом формула примет вид:
#
# <h4 align="center"> $ P(C|O) = \frac{ P(o_1, o_2, ... , o_n)P(C) }{ P(o_1, o_2, ... , o_n) } $ </h4>

# %% [markdown]
# Используем «наивное» предположение о том, что переменные O зависят только от класса C, и не зависят друг от друга. Это сильно упрощение, но зачастую это работает. Числитель примет вид:
#
# (Числитель эквивалентен совместной вероятности модели, переписываем используя повторные приложения определений условной вероятности)
#
# <h4 align="center"> $P(C)P(o_1|C)P(o_2|C_{o1})...P(o_n|C_{o1o2...on})$ </h4>

# %%
from collections import defaultdict
from math import log

def train(samples):
    classes, freq = defaultdict(lambda:0), defaultdict(lambda:0) # инициализация словарей с лямбдой, чтобы можно было прибавлять к нему элементы 
    #(без лямбды ошибка что нет такого элта в словаре)

    # прохожу по кортеежам из samples (feats,label)
    for feats, label in samples: # feats = [int,int,..,int], label = int, samples = (feats,label)

        # находим лэйбл класса и считаем его частоту
        # считаю сколько раз класс (в нашем случае 0 или 1) появился раз в samples
        classes[label] += 1     

        # feats - элемент обучающей выборки, наш обзор     
        # [1, 14, 22, 16, 43, ... <- закодированные в словаре наборы слов    
        # прохожу по списку из feats = [int,int..,int] - это слова в нашем предложении/тексте
        # и считаю сколько раз встретилось слово в данном тексте. Каждому Тексту соответствует класс (label)
        # получаю словарь кортежей (класс, слово) : количество раз сколько слово встретилось с этим классом из всех samples
        for feat in feats:
            # проходимся по всем словам и считаем их частоты (кол-во элементов)
            # ключ - (лейбл, слово) (пример (0, 11176): 26 )
            freq[label, feat] += 1          # count features frequencies, freq - (int, int from [int, int..]) : int
            # внутри freq содержится записи формата (лейбл(1 или 0 в нашем случае), слово(133)) : кол-во встречаний в тексте

    # нормализуем частоты фичей и классов
    # распаковываем лейбл и фичу из частот, делим на кол-во элементов этого класса
    # cчитаю вероятность P(O_i|C), т.е вероятность встретить слово O_i с таким-то классом С (0 или 1 в нашем случ)
    for label, feat in freq:
        # делю количество раз сколько слово встретилось с этим классоми из всех samples на количество того или иного класса в samples               
        freq[label, feat] /= classes[label] # для получения частоты нормируем на кол-во элементов в классе
        
    # кол-во элементов для каждого класса делим на кол-во семплов
    # делю значение сколько раз класс появился в samples на количество всех классов появившихся в samples
    # например класс 0 встретился 10 раз, класс 1 20 раз, всего классов из samples будет равно 30
    # тогда вероятность встретить класс 0 = 10/30, класс 1 = 20/30
    for c in classes:
        classes[c] /= len(samples)

    # мы получили classes - соответсвует вероятности P(C)
    # и freq - вероятности P(O|C)
    return classes, freq

# %%
defaultdict(lambda:0)
# Out:
# defaultdict(<function __main__.<lambda>()>, {})

# %%
tt = defaultdict(lambda:0)
tt[1] = 'a'
tt
tt[2] = 'b'
tt
tt[1,'c'] = 3
tt
# Out:
# defaultdict(<function __main__.<lambda>()>, {1: 'a', 2: 'b', (1, 'c'): 3})

# %%
t_d = defaultdict(lambda:0)
t_d 
for x in [0,1,2,3,4,5]:
  t_d[0,x]+=1
t_d
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(0, 0): 1, (0, 1): 1, (0, 2): 1, (0, 3): 1, (0, 4): 1, (0, 5): 1})

# %%
t_d.get(0,5)
# Out:
# 5

# %% [markdown]
# В функции train первые пять строк производят подсчет количества классов C, а также частоту появления фич O и С в одном семпле. Вторая часть метода просто нормирует эти частоты. Таким образом на выходе получаются вероятности $P(C)$ и $P(O|C)$.

# %%
def classify(classifier, feats):
    classes, prob = classifier
    '''
    print(classes)
    print(prob)
    
    print(-log(classes[0]) + sum(-log(prob.get((0,feat), 10**(-7))) for feat in feats) )
    print(-log(classes[1]) + sum(-log(prob.get((1,feat), 10**(-7))) for feat in feats) )
    '''
    # max ( P(1|O), P(0|O))
    
    # argmin(-log(C|O))

    # здесь по сути формула С=𝑎𝑟𝑔𝑚𝑎𝑥𝑐𝑃с,только исп-ся аргмин и минусы в формуле
    # формула 𝑃(𝐶|𝑂) = 𝑃(𝐶)𝑃(𝑜1|𝐶)𝑃(𝑜2|𝐶𝑜1)...𝑃(𝑜𝑛|𝐶𝑜1𝑜2...𝑜𝑛) толко вместо умножения сумма логарифмов
    # 𝑃(𝐶) - верть появления класса С (0 или 1)
    # P(O_i|C) - верть появления слова О_i в классе С
    # функцией мин выбирается тот класс где значение функции 𝑃(𝐶|𝑂)(посчитанное для каждого класса) меньше
    # так предсказывается класс для текста с набором слов
    return min(classes.keys(),
        key = lambda cl: -log(classes[cl]) + sum(-log(prob.get((cl,feat), 10**(-7))) for feat in feats) )

# %% [markdown]
# В функции classify происходит поиск наиболее вероятного класса. Тут заменяется произведение вероятностей на сумму логарифмов, взятых с отрицательным знаком, и вычисляю не argmax, а argmin. Переход к логарифмам — распространненный прием чтобы избежать слишком маленьких чисел, которые могли бы получится при произведении вероятностей + логарифм – монотонно возрастающая функция. Логарифм от функции достигнет максимума в той же точке (по оси абсцисс), что и сама функция.
# Число 10(^-7), которое подставляется в логарифм, это способ избежать нуля в аргументе логарифма (т.к. он будет иначе он будет неопределен).

# %% [markdown]
# формат 1 элемента обучающей выборки
# ([1, 2, 3, 123, ... <- слова], 1 <-ответ)
#
# обучающая выборка [(), (), () ]

# %%
features = [(x_train[i], y_train[i]) for i in range(len(x_train))]
# features это кортеж из ([],int), где []=xtrain[i], int = y_train[i]

# %%
features[0]
# Out:
# ([1,
#   14,
#   22,
#   16,
#   43,
#   530,
#   973,
#   1622,
#   1385,
#   65,
#   458,
#   4468,
#   66,
#   3941,
#   4,
#   173,
#   36,
#   256,
#   5,
#   25,
#   100,
#   43,
#   838,
#   112,
#   50,
#   670,
#   22665,
#   9,
#   35,
#   480,
#   284,
#   5,
#   150,
#   4,
#   172,
#   112,
#   167,
#   21631,
#   336,
#   385,
#   39,
#   4,
#   172,
#   4536,
#   1111,
#   17,
#   546,
#   38,
#   13,
#   447,
#   4,
#   192,
#   50,
#   16,
#   6,
#   147,
#   2025,
#   19,
#   14,
#   22,
#   4,
#   1920,
#   4613,
#   469,
#   4,
#   22,
#   71,
#   87,
#   12,
#   16,
#   43,
#   530,
#   38,
#   76,
#   15,
#   13,
#   1247,
#   4,
#   22,
#   17,
#   515,
#   17,
#   12,
#   16,
#   626,
#   18,
#   19193,
#   5,
#   62,
#   386,
#   12,
#   8,
#   316,
#   8,
#   106,
#   5,
#   4,
#   2223,
#   5244,
#   16,
#   480,
#   66,
#   3785,
#   33,
#   4,
#   130,
#   12,
#   16,
#   38,
#   619,
#   5,
#   25,
#   124,
#   51,
#   36,
#   135,
#   48,
#   25,
#   1415,
#   33,
#   6,
#   22,
#   12,
#   215,
#   28,
#   77,
#   52,
#   5,
#   14,
#   407,
#   16,
#   82,
#   10311,
#   8,
#   4,
#   107,
#   117,
#   5952,
#   15,
#   256,
#   4,
#   31050,
#   7,
#   3766,
#   5,
#   723,
#   36,
#   71,
#   43,
#   530,
#   476,
#   26,
#   400,
#   317,
#   46,
#   7,
#   4,
#   12118,
#   1029,
#   13,
#   104,
#   88,
#   4,
#   381,
#   15,
#   297,
#   98,
#   32,
#   2071,
#   56,
#   26,
#   141,
#   6,
#   194,
#   7486,
#   18,
#   4,
#   226,
#   22,
#   21,
#   134,
#   476,
#   26,
#   480,
#   5,
#   144,
#   30,
#   5535,
#   18,
#   51,
#   36,
#   28,
#   224,
#   92,
#   25,
#   104,
#   4,
#   226,
#   65,
#   16,
#   38,
#   1334,
#   88,
#   12,
#   16,
#   283,
#   5,
#   16,
#   4472,
#   113,
#   103,
#   32,
#   15,
#   16,
#   5345,
#   19,
#   178,
#   32],
#  1)

# %%
classifier = train(features)

# %%
classifier[0]
# Out:
# defaultdict(<function __main__.train.<locals>.<lambda>()>, {1: 0.5, 0: 0.5})

# %%
classifier[1]
# Out:
# defaultdict(<function __main__.train.<locals>.<lambda>()>,
#             {(1, 1): 1.0,
#              (1, 14): 2.80568,
#              (1, 22): 1.62928,
#              (1, 16): 1.7528,
#              (1, 43): 0.57144,
#              (1, 530): 0.074,
#              (1, 973): 0.0244,
#              (1, 1622): 0.01352,
#              (1, 1385): 0.01656,
#              (1, 65): 0.53696,
#              (1, 458): 0.05088,
#              (1, 4468): 0.0044,
#              (1, 66): 0.43792,
#              (1, 3941): 0.00456,
#              (1, 4): 13.8392,
#              (1, 173): 0.16768,
#              (1, 36): 0.73648,
#              (1, 256): 0.12568,
#              (1, 5): 7.17752,
#              (1, 25): 1.1784,
#              (1, 100): 0.25432,
#              (1, 838): 0.02568,
#              (1, 112): 0.2572,
#              (1, 50): 0.54824,
#              (1, 670): 0.04544,
#              (1, 22665): 0.00048,
#              (1, 9): 4.57904,
#              (1, 35): 0.9024,
#              (1, 480): 0.08464,
#              (1, 284): 0.09416,
#              (1, 150): 0.18904,
#              (1, 172): 0.15776,
#              (1, 167): 0.15376,
#              (1, 21631): 0.00056,
#              (1, 336): 0.10208,
#              (1, 385): 0.07128,
#              (1, 39): 0.86144,
#              (1, 4536): 0.00448,
#              (1, 1111): 0.016,
#              (1, 17): 2.10432,
#              (1, 546): 0.03872,
#              (1, 38): 0.73152,
#              (1, 13): 2.90368,
#              (1, 447): 0.08696,
#              (1, 192): 0.13464,
#              (1, 6): 6.69344,
#              (1, 147): 0.20448,
#              (1, 2025): 0.00976,
#              (1, 19): 1.8596,
#              (1, 1920): 0.01544,
#              (1, 4613): 0.00368,
#              (1, 469): 0.06384,
#              (1, 71): 0.38248,
#              (1, 87): 0.51272,
#              (1, 12): 3.1492,
#              (1, 76): 0.3748,
#              (1, 15): 2.73672,
#              (1, 1247): 0.0176,
#              (1, 515): 0.05616,
#              (1, 626): 0.04688,
#              (1, 18): 1.79296,
#              (1, 19193): 0.00064,
#              (1, 62): 0.42688,
#              (1, 386): 0.07992,
#              (1, 8): 5.3388,
#              (1, 316): 0.0932,
#              (1, 106): 0.27376,
#              (1, 2223): 0.00856,
#              (1, 5244): 0.00352,
#              (1, 3785): 0.00712,
#              (1, 33): 0.89856,
#              (1, 130): 0.21528,
#              (1, 619): 0.03968,
#              (1, 124): 0.22632,
#              (1, 51): 0.5932,
#              (1, 135): 0.19288,
#              (1, 48): 0.58208,
#              (1, 1415): 0.02176,
#              (1, 215): 0.13696,
#              (1, 28): 1.0068,
#              (1, 77): 0.33512,
#              (1, 52): 0.61624,
#              (1, 407): 0.08344,
#              (1, 82): 0.44392,
#              (1, 10311): 0.00128,
#              (1, 107): 0.29816,
#              (1, 117): 0.26664,
#              (1, 5952): 0.00288,
#              (1, 31050): 0.00024,
#              (1, 7): 6.148,
#              (1, 3766): 0.00672,
#              (1, 723): 0.04624,
#              (1, 476): 0.05992,
#              (1, 26): 1.1844,
#              (1, 400): 0.0776,
#              (1, 317): 0.0764,
#              (1, 46): 0.64936,
#              (1, 12118): 0.0008,
#              (1, 1029): 0.02072,
#              (1, 104): 0.29224,
#              (1, 88): 0.32632,
#              (1, 381): 0.0708,
#              (1, 297): 0.09864,
#              (1, 98): 0.30408,
#              (1, 32): 0.95408,
#              (1, 2071): 0.01096,
#              (1, 56): 0.5048,
#              (1, 141): 0.2072,
#              (1, 194): 0.144,
#              (1, 7486): 0.0016,
#              (1, 226): 0.1048,
#              (1, 21): 1.66544,
#              (1, 134): 0.21552,
#              (1, 144): 0.168,
#              (1, 30): 0.99312,
#              (1, 5535): 0.00288,
#              (1, 224): 0.12672,
#              (1, 92): 0.264,
#              (1, 1334): 0.02384,
#              (1, 283): 0.11808,
#              (1, 4472): 0.00216,
#              (1, 113): 0.33192,
#              (1, 103): 0.30376,
#              (1, 5345): 0.00416,
#              (1, 178): 0.17272,
#              (0, 1): 1.0,
#              (0, 194): 0.132,
#              (0, 1153): 0.02336,
#              (0, 8255): 0.0024,
#              (0, 78): 0.58992,
#              (0, 228): 0.10488,
#              (0, 5): 5.95024,
#              (0, 6): 6.34976,
#              (0, 1463): 0.0188,
#              (0, 4369): 0.00336,
#              (0, 5012): 0.00312,
#              (0, 134): 0.21792,
#              (0, 26): 1.1696,
#              (0, 4): 13.05264,
#              (0, 715): 0.03576,
#              (0, 8): 5.51784,
#              (0, 118): 0.16728,
#              (0, 1634): 0.01544,
#              (0, 14): 3.27224,
#              (0, 394): 0.1112,
#              (0, 20): 1.97672,
#              (0, 13): 3.26768,
#              (0, 119): 0.16928,
#              (0, 954): 0.0324,
#              (0, 189): 0.17024,
#              (0, 102): 0.32536,
#              (0, 207): 0.14456,
#              (0, 110): 0.26112,
#              (0, 3103): 0.0064,
#              (0, 21): 1.74208,
#              (0, 69): 0.49128,
#              (0, 188): 0.15608,
#              (0, 30): 1.16272,
#              (0, 23): 1.37488,
#              (0, 7): 5.51976,
#              (0, 249): 0.19816,
#              (0, 126): 0.26072,
#              (0, 93): 0.36288,
#              (0, 114): 0.33072,
#              (0, 9): 4.006,
#              (0, 2300): 0.01312,
#              (0, 1523): 0.0192,
#              (0, 647): 0.0632,
#              (0, 116): 0.32376,
#              (0, 35): 0.82064,
#              (0, 8163): 0.00296,
#              (0, 229): 0.16472,
#              (0, 340): 0.09344,
#              (0, 1322): 0.03072,
#              (0, 130): 0.23608,
#              (0, 4901): 0.00216,
#              (0, 19): 1.67016,
#              (0, 1002): 0.02816,
#              (0, 89): 0.3732,
#              (0, 29): 0.97448,
#              (0, 952): 0.0272,
#              (0, 46): 0.718,
#              (0, 37): 0.76848,
#              (0, 455): 0.07008,
#              (0, 45): 0.68688,
#              (0, 43): 0.84928,
#              (0, 38): 0.91536,
#              (0, 1543): 0.01776,
#              (0, 1905): 0.01552,
#              (0, 398): 0.06632,
#              (0, 1649): 0.01472,
#              (0, 6853): 0.00336,
#              (0, 163): 0.18608,
#              (0, 11): 3.49904,
#              (0, 3215): 0.00568,
#              (0, 10156): 0.00112,
#              (0, 775): 0.03216,
#              (0, 11596): 0.00104,
#              (0, 349): 0.06344,
#              (0, 2637): 0.00848,
#              (0, 148): 0.17688,
#              (0, 605): 0.04968,
#              (0, 15358): 0.00072,
#              (0, 8003): 0.00184,
#              (0, 15): 2.84624,
#              (0, 123): 0.22456,
#              (0, 125): 0.28456,
#              (0, 68): 0.422,
#              (0, 23141): 0.00024,
#              (0, 165): 0.19592,
#              (0, 4362): 0.00448,
#              (0, 98): 0.33304,
#              (0, 36893): 0.00024,
#              (0, 1157): 0.03016,
#              (0, 299): 0.06672,
#              (0, 120): 0.26472,
#              (0, 174): 0.1476,
#              (0, 220): 0.12576,
#              (0, 175): 0.16176,
#              (0, 136): 0.22416,
#              (0, 50): 0.71056,
#              (0, 4373): 0.00528,
#              (0, 25249): 0.00032,
#              (0, 656): 0.03704,
#              (0, 245): 0.11712,
#              (0, 2350): 0.00976,
#              (0, 9837): 0.00112,
#              (0, 131): 0.18256,
#              (0, 152): 0.208,
#              (0, 491): 0.04984,
#              (0, 18): 1.75384,
#              (0, 46151): 8e-05,
#              (0, 32): 0.96216,
#              (0, 7464): 0.00288,
#              (0, 1212): 0.0204,
#              (0, 371): 0.05808,
#              (0, 22): 1.49832,
#              (0, 625): 0.03256,
#              (0, 64): 0.54232,
#              (0, 1382): 0.01184,
#              (0, 168): 0.17944,
#              (0, 145): 0.19352,
#              (0, 1690): 0.018,
#              (0, 16): 2.1028,
#              (0, 1355): 0.0168,
#              (0, 28): 1.21128,
#              (0, 52): 0.59176,
#              (0, 154): 0.17616,
#              (0, 462): 0.06304,
#              (0, 33): 0.982,
#              (0, 285): 0.09512,
#              (0, 95): 0.38056,
#              (0, 47): 0.60832,
#              (0, 31): 1.04144,
#              (0, 108): 0.2452,
#              (0, 5974): 0.00288,
#              (0, 54): 0.53768,
#              (0, 61): 0.48056,
#              (0, 369): 0.06408,
#              (0, 71): 0.48016,
#              (0, 149): 0.2108,
#              (0, 112): 0.27112,
#              (0, 2401): 0.00904,
#              (0, 311): 0.09208,
#              (0, 12): 3.17544,
#              (0, 3711): 0.00584,
#              (0, 75): 0.38048,
#              (0, 1829): 0.01712,
#              (0, 296): 0.09136,
#              (0, 86): 0.34424,
#              (0, 320): 0.1072,
#              (0, 534): 0.06232,
#              (0, 263): 0.0844,
#              (0, 4821): 0.00512,
#              (0, 1301): 0.0056,
#              (0, 1873): 0.01248,
#              (0, 66): 0.5008,
#              (0, 360): 0.08168,
#              (0, 58): 0.49536,
#              (0, 316): 0.07672,
#              (0, 334): 0.09304,
#              (0, 1716): 0.01488,
#              (0, 645): 0.0436,
#              (0, 662): 0.04496,
#              (0, 257): 0.076,
#              (0, 85): 0.34152,
#              (0, 1200): 0.0192,
#              (0, 42): 0.82144,
#              (0, 1228): 0.02024,
#              (0, 2578): 0.00848,
#              (0, 83): 0.36536,
#              (0, 3912): 0.00496,
#              (0, 36): 0.95464,
#              (0, 1539): 0.0212,
#              (0, 278): 0.13064,
#              (0, 44076): 0.00016,
#              (0, 780): 0.02648,
#              (0, 106): 0.28392,
#              (0, 6905): 0.00344,
#              (0, 1338): 0.02744,
#              (0, 215): 0.11888,
#              (0, 610): 0.0536,
#              (0, 40): 0.89896,
#              (0, 87): 0.21088,
#              (0, 326): 0.1048,
#              (0, 272): 0.122,
#              (0, 57): 0.65016,
#              (0, 2307): 0.01312,
#              (0, 51): 0.63472,
#              (0, 170): 0.18512,
#              (0, 595): 0.07136,
#              (0, 1352): 0.01472,
#              (0, 191): 0.16704,
#              (0, 79): 0.40112,
#              (0, 638): 0.03856,
#              (0, 51428): 0.00016,
#              (0, 607): 0.05968,
#              (0, 624): 0.04488,
#              (0, 227): 0.10376,
#              (0, 129): 0.25816,
#              (0, 113): 0.19256,
#              (1, 18609): 0.00056,
#              (1, 16085): 0.00088,
#              (1, 2804): 0.00824,
#              (1, 2040): 0.01416,
#              (1, 432): 0.05056,
#              (1, 111): 0.30128,
#              (1, 153): 0.22008,
#              (1, 1494): 0.0164,
#              (1, 70): 0.44472,
#              (1, 131): 0.26696,
#              (1, 67): 0.4812,
#              (1, 11): 4.01568,
#              (1, 61): 0.5188,
#              (1, 15305): 0.00104,
#              (1, 744): 0.03848,
#              (1, 3715): 0.00648,
#              (1, 761): 0.0348,
#              (1, 5766): 0.00272,
#              (1, 452): 0.06544,
#              (1, 9214): 0.0016,
#              (1, 985): 0.02944,
#              (1, 64317): 8e-05,
#              (1, 59): 0.56136,
#              (1, 166): 0.19096,
#              (1, 105): 0.27992,
#              (1, 216): 0.12728,
#              (1, 1239): 0.0184,
#              (1, 41): 0.83696,
#              (1, 1797): 0.0148,
#              (1, 2413): 0.01016,
#              (1, 31): 1.0796,
#              (1, 687): 0.04416,
#              (1, 23): 1.36016,
#              (1, 33929): 8e-05,
#              (1, 7339): 0.00184,
#              (1, 3693): 0.00424,
#              (1, 42): 0.61808,
#              (1, 121): 0.25224,
#              (1, 456): 0.07112,
#              (1, 10): 3.9388,
#              (1, 265): 0.10856,
#              (1, 575): 0.03872,
#              (1, 159): 0.17384,
#              (1, 1447): 0.01888,
#              (1, 586): 0.02888,
#              (1, 482): 0.03384,
#              (1, 96): 0.32264,
#              (1, 716): 0.04432,
#              (1, 579): 0.04824,
#              (1, 6004): 0.0032,
#              (1, 1615): 0.01568,
#              (1, 23005): 0.00048,
#              (1, 5168): 0.00392,
#              (1, 7064): 0.00272,
#              (1, 464): 0.0636,
#              (1, 314): 0.08504,
#              (1, 87564): 8e-05,
#              (1, 719): 0.036,
#              (1, 605): 0.03224,
#              (1, 202): 0.12408,
#              (1, 27): 1.37784,
#              (1, 310): 0.09328,
#              (1, 3772): 0.00464,
#              (1, 3501): 0.00536,
#              (1, 2722): 0.00752,
#              (1, 58): 0.5192,
#              (1, 537): 0.05552,
#              (1, 2116): 0.01048,
#              (1, 180): 0.13816,
#              (1, 40): 0.7228,
#              (1, 413): 0.07328,
#              (1, 263): 0.116,
#              (1, 37): 0.87944,
#              (1, 152): 0.15456,
#              (1, 377): 0.07784,
#              (1, 846): 0.03448,
#              (1, 54): 0.59632,
#              (1, 75): 0.4088,
#              (1, 2504): 0.00792,
#              (1, 182): 0.18808,
#              (1, 2306): 0.01128,
#              (1, 922): 0.03144,
#              (1, 279): 0.07496,
#              (1, 2895): 0.00672,
#              (1, 2867): 0.0076,
#              (1, 921): 0.0356,
#              (1, 18435): 0.00032,
#              (1, 1219): 0.02216,
#              (1, 3890): 0.0068,
#              (1, 20523): 0.0004,
#              (1, 217): 0.15696,
#              (1, 4122): 0.00336,
#              (1, 1710): 0.00936,
#              (1, 20341): 0.00064,
#              (1, 1236): 0.0252,
#              (1, 736): 0.03672,
#              (1, 403): 0.05456,
#              (1, 47289): 0.00016,
#              (1, 4494): 0.00472,
#              (1, 90): 0.40088,
#              (1, 2311): 0.00952,
#              (1, 4319): 0.00496,
#              (1, 309): 0.0984,
#              (1, 9225): 0.00088,
#              (1, 145): 0.2032,
#              (1, 143): 0.19272,
#              (1, 5122): 0.00384,
#              (1, 7039): 0.00224,
#              (1, 746): 0.0364,
#              (1, 7979): 0.00136,
#              (1, 18665): 0.0004,
#              (1, 594): 0.03088,
#              (1, 94): 0.36432,
#              (1, 9096): 0.0024,
#              (1, 3987): 0.0056,
#              (1, 15242): 0.0008,
#              (1, 28280): 0.00024,
#              (1, 538): 0.04,
#              (1, 1795): 0.0132,
#              (1, 246): 0.12424,
#              (1, 56615): 8e-05,
#              (1, 10161): 0.00128,
#              (1, 635): 0.04816,
#              (1, 408): 0.08248,
#              (1, 318): 0.08032,
#              (1, 1382): 0.02064,
#              (1, 47): 0.73488,
#              (1, 2683): 0.00936,
#              (1, 936): 0.03848,
#              (1, 6307): 0.0032,
#              (1, 10197): 0.00176,
#              (1, 49): 0.59528,
#              (1, 1885): 0.0184,
#              (1, 13699): 0.00128,
#              (1, 1118): 0.02584,
#              (1, 80): 0.41672,
#              (1, 126): 0.21824,
#              (1, 842): 0.02928,
#              (1, 18223): 0.00056,
#              (1, 4726): 0.00456,
#              (1, 1550): 0.0132,
#              (1, 3633): 0.00512,
#              (1, 341): 0.07808,
#              (1, 29): 1.18168,
#              (1, 2733): 0.01112,
#              (1, 4185): 0.00448,
#              (1, 16376): 0.00088,
#              (1, 1784): 0.01176,
#              (1, 86): 0.38032,
#              (1, 1117): 0.02648,
#              (1, 3261): 0.00512,
#              (1, 25837): 0.00024,
#              (1, 2841): 0.00752,
#              (1, 1010): 0.02776,
#              (1, 26747): 0.0004,
#              (1, 793): 0.03904,
#              (1, 1386): 0.01472,
#              (1, 1830): 0.01328,
#              (1, 2750): 0.01,
#              (1, 1944): 0.01248,
#              (1, 882): 0.03144,
#              (1, 496): 0.05048,
#              (1, 33029): 0.00032,
#              (1, 2213): 0.00912,
#              (1, 127): 0.24512,
#              (1, 494): 0.0536,
#              (1, 1906): 0.01072,
#              (1, 97): 0.26376,
#              (1, 236): 0.12328,
#              (1, 11120): 0.00176,
#              (1, 1311): 0.02656,
#              (1, 23643): 0.0004,
#              (1, 29851): 0.00024,
#              (1, 91): 0.38904,
#              (1, 22793): 0.00064,
#              (1, 44): 0.66496,
#              (1, 11876): 0.00112,
#              (1, 1775): 0.00984,
#              (1, 3353): 0.0068,
#              (1, 12716): 0.00112,
#              (1, 1846): 0.01544,
#              (1, 11286): 0.00128,
#              (1, 154): 0.18368,
#              (1, 518): 0.05968,
#              (1, 53): 0.6016,
#              (1, 13243): 0.00104,
#              (1, 3211): 0.00608,
#              (1, 399): 0.05416,
#              (1, 257): 0.1304,
#              (1, 3807): 0.00416,
#              (1, 205): 0.16104,
#              (1, 33058): 0.00032,
#              (1, 10359): 0.00136,
#              (1, 242): 0.11184,
#              (1, 1202): 0.02136,
#              (1, 11377): 0.00192,
#              (1, 2070): 0.0124,
#              (1, 307): 0.1264,
#              (1, 93): 0.3056,
#              (1, 188): 0.13064,
#              (1, 1076): 0.02336,
#              (1, 3222): 0.0032,
#              (1, 13465): 0.00088,
#              (1, 2348): 0.0068,
#              (1, 33195): 0.00024,
#              (1, 280): 0.10336,
#              (1, 219): 0.13536,
#              (1, 52788): 8e-05,
#              (1, 431): 0.06616,
#              (1, 758): 0.0336,
#              (1, 859): 0.0288,
#              (1, 953): 0.02176,
#              (1, 1052): 0.02536,
#              (1, 12283): 0.00088,
#              (1, 5991): 0.0048,
#              (1, 238): 0.10032,
#              (1, 60): 0.39704,
#              (1, 35410): 8e-05,
#              (1, 15812): 0.00088,
#              (1, 804): 0.03872,
#              (1, 27767): 0.00024,
#              (1, 9941): 0.0004,
#              (1, 132): 0.25864,
#              (1, 955): 0.03792,
#              (1, 22148): 0.00032,
#              (1, 1685): 0.01888,
#              (1, 195): 0.11632,
#              (1, 796): 0.02992,
#              (1, 13713): 0.0008,
#              (1, 671): 0.04104,
#              (1, 559): 0.0552,
#              (1, 888): 0.02616,
#              (1, 726): 0.03576,
#              (1, 7008): 0.00288,
#              (1, 566): 0.03896,
#              (1, 64): 0.41088,
#              (1, 2574): 0.00808,
#              (0, 1323): 0.02232,
#              (0, 10): 4.21088,
#              (0, 1637): 0.0144,
#              (0, 56): 0.55712,
#              (0, 457): 0.06128,
#              (0, 88): 0.3972,
#              (0, 2626): 0.01048,
#              (0, 1400): 0.02016,
#              (0, 3171): 0.00488,
#              (0, 70): 0.44488,
#              (0, 49): 0.66416,
#              (0, 706): 0.05512,
#              (0, 919): 0.0292,
#              (0, 355): 0.09232,
#              (0, 1696): 0.01184,
#              (0, 96): 0.31872,
#              (0, 143): 0.2048,
#              (0, 289): 0.08664,
#              (0, 2359): 0.01344,
#              (0, 2073): 0.0096,
#              (0, 473): 0.06376,
#              (0, 569): 0.03712,
#              (0, 419): 0.0712,
#              (0, 429): 0.05296,
#              (0, 1513): 0.01376,
#              (0, 474): 0.06024,
#              (0, 570): 0.0492,
#              (0, 25): 1.21176,
#              (0, 124): 0.26616,
#              (0, 138): 0.27648,
#              (0, 421): 0.06664,
#              (0, 725): 0.03248,
#              (0, 6397): 0.00344,
#              (0, 1571): 0.01584,
#              (0, 22016): 0.00064,
#              (0, 3524): 0.0068,
#              (0, 128): 0.26864,
#              (0, 74): 0.41464,
#              (0, 233): 0.14968,
#              (0, 224): 0.1208,
#              (0, 562): 0.04248,
#              (0, 298): 0.07768,
#              (0, 2167): 0.00976,
#              (0, 1272): 0.01944,
#              (0, 2601): 0.00808,
#              (0, 516): 0.058,
#              (0, 988): 0.01992,
#              (0, 784): 0.03552,
#              (0, 7224): 0.00232,
#              (0, 226): 0.14144,
#              (0, 251): 0.0888,
#              (0, 778): 0.02384,
#              (0, 630): 0.04072,
#              (0, 1766): 0.01224,
#              (0, 7982): 0.002,
#              (0, 1051): 0.02304,
#              (0, 43222): 0.00016,
#              (0, 156): 0.19192,
#              (0, 139): 0.22264,
#              (0, 121): 0.25344,
#              (0, 664): 0.03008,
#              (0, 665): 0.04456,
#              (0, 1361): 0.02008,
#              (0, 173): 0.15448,
#              (0, 749): 0.02896,
#              (0, 86588): 8e-05,
#              (0, 3804): 0.00416,
#              (0, 65): 0.4144,
#              (0, 127): 0.22912,
#              (0, 24): 1.30768,
#              (0, 15344): 0.00048,
#              (1, 6740): 0.00344,
#              (1, 365): 0.06296,
#              (1, 1234): 0.0184,
#              (1, 1156): 0.0292,
#              (1, 354): 0.09896,
#              (1, 5327): 0.00424,
#              (1, 6638): 0.00168,
#              (1, 1016): 0.03112,
#              (1, 10626): 0.00184,
#              (1, 5940): 0.00272,
#              (1, 356): 0.09472,
#              (1, 1349): 0.02192,
#              (1, 500): 0.05816,
#              (1, 200): 0.16128,
#              (1, 4132): 0.00424,
#              (1, 16393): 0.0008,
#              (1, 9363): 0.00224,
#              (1, 1831): 0.0152,
#              (1, 7485): 0.00344,
#              (1, 4831): 0.00344,
#              (1, 71690): 8e-05,
#              (1, 4183): 0.00496,
#              (1, 369): 0.07768,
#              (1, 1345): 0.01312,
#              (1, 32677): 0.00032,
#              (1, 1838): 0.01104,
#              (1, 1974): 0.0128,
#              (1, 119): 0.34208,
#              (1, 85): 0.3848,
#              (1, 486): 0.05848,
#              (1, 26441): 0.0004,
#              (1, 8564): 0.00176,
#              (1, 63): 0.50112,
#              (1, 271): 0.09488,
#              (1, 196): 0.13504,
#              (1, 949): 0.02752,
#              (1, 4121): 0.00336,
#              (1, 74170): 8e-05,
#              (1, 2212): 0.0096,
#              (1, 2436): 0.00872,
#              (1, 819): 0.02592,
#              (1, 7175): 0.00232,
#              (1, 227): 0.14048,
#              (1, 2494): 0.00952,
#              (1, 33740): 0.00024,
#              (1, 423): 0.07376,
#              (1, 168): 0.15168,
#              (1, 89): 0.3364,
#              (1, 665): 0.03104,
#              (1, 270): 0.10192,
#              (1, 197): 0.13088,
#              (1, 161): 0.13352,
#              (1, 5390): 0.00288,
#              (1, 99): 0.29224,
#              (1, 77842): 8e-05,
#              (1, 419): 0.05128,
#              (1, 108): 0.30408,
#              (1, 2084): 0.0092,
#              (1, 4773): 0.00408,
#              (1, 81): 0.31496,
#              (1, 55): 0.66416,
#              (1, 1901): 0.01152,
#              (0, 14906): 0.0012,
#              (0, 716): 0.02616,
#              (0, 689): 0.03432,
#              (0, 4367): 0.00288,
#              (0, 6308): 0.002,
#              (0, 2343): 0.00816,
#              (0, 4804): 0.00352,
#              (0, 28674): 0.0004,
#              (0, 84206): 8e-05,
#              (0, 5270): 0.00384,
#              (0, 32099): 0.00024,
#              (0, 2315): 0.00624,
#              (0, 71688): 8e-05,
#              (0, 12572): 0.00032,
#              (0, 24785): 0.00032,
#              (0, 43394): 0.00016,
#              (0, 10993): 0.00072,
#              (0, 628): 0.02936,
#              (0, 7685): 0.00176,
#              (0, 150): 0.17848,
#              (0, 9820): 0.00112,
#              (0, 4069): 0.00384,
#              (0, 2909): 0.0068,
#              (0, 16287): 0.0004,
#              (0, 847): 0.02976,
#              (0, 313): 0.08448,
#              (0, 176): 0.15104,
#              (0, 63860): 8e-05,
#              (0, 6202): 0.00264,
#              (0, 4434): 0.0028,
#              (0, 183): 0.14688,
#              (0, 192): 0.14712,
#              (0, 27): 0.97144,
#              (0, 5842): 0.00232,
#              (0, 799): 0.02712,
#              (0, 7101): 0.00296,
#              (0, 39455): 8e-05,
#              (0, 588): 0.03296,
#              (0, 84): 0.3772,
#              (0, 3231): 0.00664,
#              (0, 339): 0.0724,
#              (0, 5206): 0.00168,
#              (0, 4869): 0.00232,
#              (0, 30497): 0.00032,
#              (0, 6293): 0.0028,
#              (0, 345): 0.09464,
#              (0, 37377): 0.00024,
#              (0, 142): 0.23416,
#              (0, 218): 0.14776,
#              (0, 208): 0.12952,
#              (0, 853): 0.02616,
#              (0, 659): 0.02856,
#              (0, 882): 0.02392,
#              (0, 80): 0.31872,
#              (0, 115): 0.26072,
#              (0, 172): 0.16624,
#              (0, 1001): 0.02352,
#              (0, 1055): 0.022,
#              (0, 526): 0.04544,
#              (0, 34): 0.8436,
#              (0, 3717): 0.00384,
#              (0, 68395): 8e-05,
#              (0, 5262): 0.00376,
#              (0, 63370): 8e-05,
#              (0, 17): 1.64984,
#              (0, 6706): 0.00264,
#              (0, 1094): 0.01544,
#              (0, 871): 0.02592,
#              (0, 2030): 0.01112,
#              (0, 1109): 0.02192,
#              (0, 230): 0.12952,
#              (0, 4324): 0.0016,
#              (0, 20636): 0.00016,
#              (0, 5056): 0.00312,
#              (0, 1034): 0.02992,
#              (0, 195): 0.15936,
#              (0, 301): 0.0984,
#              (0, 46035): 8e-05,
#              (0, 783): 0.03712,
#              (0, 48545): 0.00016,
#              (0, 2945): 0.00528,
#              (0, 103): 0.30704,
#              (0, 465): 0.04344,
#              (0, 16454): 0.00112,
#              (0, 845): 0.03664,
#              (0, 446): 0.06352,
#              (0, 1895): 0.0076,
#              (0, 184): 0.16904,
#              (0, 76): 0.40584,
#              (0, 5310): 0.00264,
#              (0, 197): 0.1436,
#              (0, 601): 0.05104,
#              (0, 964): 0.03488,
#              (0, 2152): 0.01496,
#              (0, 258): 0.10136,
#              (0, 1730): 0.01376,
#              (0, 338): 0.1184,
#              (0, 55): 0.4608,
#              (0, 5312): 0.00448,
#              (0, 550): 0.0524,
#              (0, 728): 0.02032,
#              (0, 1196): 0.02872,
#              (0, 1839): 0.00992,
#              (0, 1546): 0.01288,
#              (0, 8361): 0.00184,
#              (0, 602): 0.04472,
#              (0, 7304): 0.00208,
#              (0, 786): 0.0384,
#              (0, 99): 0.33352,
#              (0, 196): 0.14032,
#              (0, 11100): 0.00152,
#              (0, 5936): 0.00328,
#              (0, 225): 0.15184,
#              (0, 373): 0.12432,
#              (0, 1009): 0.02616,
#              (0, 63): 0.46216,
#              (0, 72): 0.4476,
#              (0, 1104): 0.02296,
#              (0, 1292): 0.02024,
#              (0, 11871): 0.0008,
#              (0, 1703): 0.0136,
#              (0, 803): 0.03776,
#              (0, 1004): 0.02128,
#              (0, 18763): 0.00048,
#              (0, 155): 0.228,
#              (0, 2029): 0.00984,
#              (0, 117): 0.24736,
#              (0, 430): 0.05168,
#              (0, 8941): 0.00136,
#              (0, 424): 0.09488,
#              (0, 2337): 0.01096,
#              (0, 178): 0.13016,
#              (0, 1465): 0.01656,
#              (0, 44): 0.72472,
#              (0, 898): 0.03224,
#              (0, 1686): 0.01216,
#              (0, 5623): 0.00296,
#              (0, 267): 0.1144,
#              (0, 185): 0.10408,
#              (0, 21486): 0.00056,
#              (0, 277): 0.094,
#              (0, 1188): 0.02552,
#              (0, 100): 0.36544,
#              (0, 216): 0.12752,
#              (0, 357): 0.11816,
#              (0, 10399): 0.00216,
#              (0, 367): 0.06288,
#              (0, 788): 0.03136,
#              (0, 39): 0.77808,
#              (0, 818): 0.02976,
#              (0, 162): 0.14792,
#              (0, 4165): 0.00384,
#              (0, 237): 0.11104,
#              (0, 600): 0.0552,
#              (0, 306): 0.09168,
#              (0, 157): 0.16208,
#              (0, 549): 0.05856,
#              (0, 12370): 0.00136,
#              (0, 824): 0.03096,
#              (0, 4104): 0.00312,
#              (0, 774): 0.02904,
#              (0, 77): 0.40784,
#              (0, 1059): 0.0172,
#              (0, 159): 0.17168,
#              (0, 497): 0.06312,
#              (0, 1493): 0.014,
#              (0, 453): 0.04264,
#              (0, 8651): 0.00096,
#              (0, 292): 0.0644,
#              (0, 8253): 0.00136,
#              (0, 107): 0.25296,
#              (0, 2826): 0.00664,
#              (0, 1082): 0.02808,
#              (0, 1251): 0.01704,
#              (0, 906): 0.01576,
#              (0, 1134): 0.01376,
#              (0, 244): 0.12072,
#              (0, 2519): 0.00816,
#              (0, 135): 0.23816,
#              (0, 466): 0.05088,
#              (0, 1572): 0.01384,
#              (0, 4413): 0.00424,
#              (0, 599): 0.05992,
#              (0, 133): 0.22768,
#              (0, 541): 0.05776,
#              (0, 4323): 0.00568,
#              (0, 171): 0.17248,
#              (0, 539): 0.05144,
#              (0, 11890): 0.00112,
#              (0, 164): 0.23864,
#              (0, 426): 0.08288,
#              (0, 81): 0.41792,
#              (0, 344): 0.06736,
#              (0, 4617): 0.00352,
#              (0, 10373): 0.00192,
#              (0, 12958): 0.0016,
#              (0, 5802): 0.0048,
#              (0, 629): 0.0492,
#              (0, 655): 0.04104,
#              (0, 707): 0.03272,
#              (0, 6371): 0.0016,
#              (0, 956): 0.02184,
#              (0, 1456): 0.02072,
#              (0, 841): 0.01936,
#              (0, 1310): 0.01608,
#              (0, 2493): 0.01136,
#              (0, 1467): 0.01552,
#              (0, 7722): 0.00216,
#              (0, 2828): 0.00624,
#              (0, 364): 0.09488,
#              (0, 2228): 0.01104,
#              (0, 2407): 0.00832,
#              (0, 2293): 0.00728,
#              (0, 814): 0.0296,
#              (0, 53728): 8e-05,
#              (0, 2642): 0.00608,
#              (0, 682): 0.02848,
#              (0, 352): 0.094,
#              (0, 913): 0.0452,
#              (0, 247): 0.11152,
#              (0, 2441): 0.01352,
#              (0, 1859): 0.01,
#              (0, 177): 0.1352,
#              (0, 901): 0.0364,
#              (0, 259): 0.1104,
#              (0, 6847): 0.00304,
#              (0, 14065): 0.00096,
#              (0, 3074): 0.00544,
#              (0, 199): 0.09256,
#              (0, 753): 0.05416,
#              (0, 15222): 0.00088,
#              (0, 763): 0.03544,
#              (0, 3282): 0.00688,
#              (0, 1916): 0.01792,
#              (0, 92): 0.4116,
#              (0, 202): 0.14584,
#              (0, 8848): 0.00176,
#              (0, 122): 0.27944,
#              (0, 4171): 0.00488,
#              (1, 264): 0.0856,
#              (1, 664): 0.04552,
#              (1, 1713): 0.01512,
#              (1, 1135): 0.01488,
#              (1, 20): 1.5084,
#              (1, 750): 0.028,
#              (1, 4299): 0.00584,
#              (1, 15455): 0.00096,
#              (1, 4441): 0.004,
#              (1, 102): 0.28648,
#              (1, 120): 0.24112,
#              (1, 5533): 0.00192,
#              (1, 3974): 0.00488,
#              (1, 5369): 0.00408,
#              (1, 142): 0.16976,
#              (1, 371): 0.08136,
#              (1, 571): 0.03528,
#              (1, 25242): 0.00048,
#              (1, 24762): 0.00048,
#              (1, 122): 0.22256,
#              (1, 72): 0.41176,
#              (1, 155): 0.13184,
#              (1, 170): 0.1424,
#              (1, 83): 0.36344,
#              (1, 866): 0.03232,
#              (1, 1120): 0.01688,
#              (1, 79): 0.3404,
#              (1, 547): 0.04936,
#              (1, 148): 0.19872,
#              (1, 16126): 0.00056,
#              (1, 3823): 0.0068,
#              (1, 2380): 0.00864,
#              (1, 350): 0.08432,
#              (1, 228): 0.13856,
#              (1, 269): 0.07888,
#              (1, 1314): 0.0212,
#              (1, 2347): 0.00816,
#              (1, 979): 0.02592,
#              (1, 95): 0.26864,
#              (1, 24): 1.14112,
#              (1, 3186): 0.00544,
#              (1, 40732): 0.00016,
#              (1, 84): 0.35096,
#              (1, 376): 0.06048,
#              (1, 292): 0.11744,
#              (1, 4751): 0.00448,
#              (1, 175): 0.15624,
#              (1, 561): 0.04864,
#              (1, 68): 0.48808,
#              (1, 3866): 0.00456,
#              (1, 137): 0.23184,
#              (1, 2541): 0.0088,
#              (1, 235): 0.12728,
#              (1, 333): 0.08064,
#              (1, 724): 0.02992,
#              (1, 6750): 0.00296,
#              (1, 285): 0.08968,
#              (1, 140): 0.19464,
#              (1, 3094): 0.0084,
#              (1, 1301): 0.02912,
#              (1, 6991): 0.00208,
#              (1, 3578): 0.00584,
#              (1, 2527): 0.00904,
#              (1, 7612): 0.002,
#              (1, 800): 0.03408,
#              (1, 3033): 0.00888,
#              (1, 1728): 0.01448,
#              (1, 406): 0.0796,
#              (1, 639): 0.05872,
#              (1, 118): 0.34512,
#              ...})

# %%
# -log(classes[cl]) + sum(-log(prob.get((cl,feat), 10**(-7))) for feat in feats)

# %%
classifier[0].keys()
# Out:
# dict_keys([1, 0])

# %%
classifier[0][1]
# Out:
# 0.5

# %%
classifier[0][0]
# Out:
# 0.5

# %%
min(classifier[0].keys(),key = lambda cl: classifier[0][cl] )
# Out:
# 1

# %%
lambda cl: classifier[0][cl]
# Out:
# <function __main__.<lambda>(cl)>

# %% [markdown]
# ----
#
# #### Проверка
#
# Проверим как работает на примере позитивного обзора

# %%
x_test[11]
# Out:
# [1,
#  54,
#  13,
#  86,
#  219,
#  14,
#  20,
#  11,
#  4,
#  750,
#  13,
#  16,
#  38,
#  1612,
#  12,
#  340,
#  4280,
#  11,
#  61,
#  652,
#  13,
#  161,
#  67,
#  12,
#  18,
#  6,
#  2068,
#  95,
#  872,
#  51,
#  4,
#  609,
#  903,
#  67,
#  146,
#  149,
#  32,
#  14559,
#  102,
#  150,
#  8,
#  67,
#  121,
#  12,
#  435,
#  355,
#  61,
#  482,
#  9,
#  12,
#  16,
#  19,
#  755,
#  457,
#  15,
#  16,
#  4,
#  86,
#  8,
#  27865,
#  4,
#  226,
#  13,
#  244,
#  11,
#  6,
#  925,
#  11958,
#  13,
#  67,
#  916,
#  538,
#  449,
#  71619,
#  51,
#  9,
#  1448,
#  449,
#  94,
#  6,
#  925,
#  449,
#  94,
#  24,
#  6,
#  925,
#  449,
#  858,
#  13,
#  67,
#  142,
#  3642,
#  449,
#  115,
#  330,
#  29037,
#  769,
#  148,
#  2289,
#  92,
#  60,
#  5276,
#  4,
#  953,
#  8,
#  30,
#  3057,
#  42,
#  1231,
#  8,
#  4,
#  2269,
#  39,
#  4,
#  86,
#  470,
#  102,
#  15,
#  48,
#  25,
#  219,
#  32481,
#  25,
#  26,
#  184,
#  76,
#  5822,
#  5,
#  351,
#  4,
#  86,
#  342,
#  30288,
#  8,
#  14,
#  769,
#  63,
#  93,
#  12,
#  38,
#  629,
#  11,
#  4,
#  86,
#  273,
#  164,
#  939,
#  164,
#  916,
#  4,
#  953,
#  188,
#  3057,
#  4572,
#  36,
#  385,
#  16,
#  4,
#  64,
#  31,
#  15,
#  100,
#  4866,
#  41,
#  96,
#  46,
#  7,
#  12,
#  86,
#  88,
#  7,
#  1697,
#  1265,
#  95,
#  88,
#  59,
#  69,
#  1618,
#  44,
#  4,
#  14,
#  20,
#  33,
#  222,
#  1027,
#  8,
#  1231,
#  8,
#  32,
#  15,
#  60,
#  151,
#  12,
#  16,
#  6,
#  78,
#  65,
#  12,
#  16,
#  131,
#  643,
#  14559,
#  57,
#  146,
#  184,
#  252,
#  173,
#  457,
#  16,
#  4,
#  86,
#  173,
#  8,
#  340,
#  5,
#  1254,
#  2330,
#  4,
#  14559,
#  201,
#  150,
#  36,
#  26,
#  11082,
#  300,
#  5,
#  13,
#  92,
#  60,
#  104,
#  13,
#  80,
#  106,
#  12,
#  449,
#  37,
#  244,
#  13,
#  3988,
#  13,
#  242,
#  80,
#  5,
#  242,
#  80,
#  30,
#  685,
#  174]

# %%
decode_review(x_test[11])
# Out:
# "<START> when i first saw this movie in the theater i was so angry it completely blew in my opinion i didn't see it for a decade then decided what the hell let's see i'm watching all hellraiser movies now to see where it went wrong my guess is it was with sequel 5 that was the first to implement the whole i am in a dream omg i see weird stuff oh noes what is happening oh its a dream oh its not a dream oh wait i see something spooky oh never mind sucky storyline those sequels don't even require the box to be opened or stick to the rules from the first 4 movies that if you saw pinhead you are pretty much screwed and dead the first 3 sticked to this storyline which made it so scary in the first place nothing fantasy nothing weird the box got opened boom they came was the only one that could bargain her way out of it first because of uncle frank then because she had information about the this movie at least attempts to stick to all that even though it was a bad story it was still somewhat hellraiser no i'm pretty sure part 5 was the first part to completely and utterly destroy the hellraiser series now they are remaking 1 and i don't even think i will watch it oh who am i kidding i probably will and probably will be disappointed again"

# %%
print('true label', y_test[11])
# Out:
# true label 0

# %%
print('predicted', classify(classifier, (x_test[11])) )
# Out:
# predicted 0

# %% [markdown]
# Посмотрим на пример негативного обзора

# %%
decode_review(x_test[30])
# Out:
# "<START> tim robbins did a masterful job directing this film i say this because he avoided convention and cliché he also oversaw superb performances from susan sarandon who won an oscar for her role and sean penn even more amazing robbins doesn't patronize he just tells the story and lets the events play on the viewer's mind this is so effective because it allows the viewer to form his own opinions on the death penalty one of the most controversial subjects of our time without being unfairly manipulated in either direction i can't recommend this film enough 9 10"

# %%
print('true label', y_test[30])
# Out:
# true label 1

# %%
print('predicted', classify(classifier, (x_test[30])) )
# Out:
# predicted 1

# %% [markdown]
# ----
#
# Надо проверить все это на метриках качества

# %%
from sklearn.metrics import classification_report

predicted = [classify(classifier, (x_test[i])) for i in range(len(x_test))]

# %%
predicted[:5]
# Out:
# [0, 1, 1, 0, 1]

# %%
y_test[:5]
# Out:
# array([0, 1, 1, 0, 1])

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79     12500
#            1       0.79      0.79      0.79     12500
#
#     accuracy                           0.79     25000
#    macro avg       0.79      0.79      0.79     25000
# weighted avg       0.79      0.79      0.79     25000

# %% [markdown]
# ----

# %% [markdown]
# # 2.Multinomial Naive Bayes
#
# Полиномиальный наивный байесовский классификатор подходит для классификации с дискретными признаками (например, количество слов для классификации текста). Полиномиальное распределение обычно требует целочисленного количества признаков. Однако, на практике, дробные, такие как tf-idf, также могут работать.

# %% [markdown]
# Оригинальный алгоритм:
#
# $$p(f_1,..., f_n|c) = \prod_{i=1}^n p(f_i|c)$$
#
# До этого момента мы ничего не говорили о распределении каждого признака. Другими словами, мы оставили $p(fi | c)$ неопределенным. Термин «Полиномиальный наивный байесовский» просто дает нам знать, что каждый $p (fi | c)$ является многочленным распределением, а не каким-либо другим распределением. Это хорошо работает для данных, которые можно легко преобразовать в счетчики, например, слова в тексте.
#
# Наивный байесовский классификатор является общим термином, который относится к условной независимости каждой из функций в модели, в то время как полиномиальный наивный байесовский классификатор является конкретным экземпляром наивного байесовского классификатора, который использует полиномиальное распределение для каждой из функций.

# %% [markdown]
# MultinomialNB реализует наивный алгоритм Байеса для полиномиально распределенных данных и является одним из двух классических наивных байесовских вариантов, используемых в классификации текста (где данные обычно представлены в виде вектора количества слов из всех слов, или как tf-idf). Распределение параметризовано векторами $θy = (θy1,…, θyn)$ для каждого класса $y$, где $n$ - количество признаков (в текстовой классификации - размер словаря), а $θyi$ - вероятность $P (xi∣y)$ $i$-го признака появиться я появляется в документе, принадлежащем к классу у.
#
# Параметры оцениваются по сглаженной версии максимального правдоподобия, то есть относительного подсчета частоты:
#
# $$\hat{\theta}_{yi} = \frac{ N_{yi} + \alpha}{N_y + \alpha n}$$
#
# Где $N_{yi} = \sum_{x \in T} x_i$ - количество раз, в котором i-й признак появляется в документа класса $y$ в обучающем наборе, а $N_{y} = \sum_{i=1}^{n} N_{yi}$ - общее количество всех признаков класса $y$.
#
# Сглаживающий параметр $α≥0$ учитывают особенности, связанные с отсутствующими признаками в обучающих выборках, и предотвращают нулевые вероятности в дальнейших вычислениях. Установка $α = 1$ называется сглаживанием Лапласа, а $α <1$ называется сглаживанием Лидстона.

# %% [markdown]
# Переписывая формулу для задачи классификация текста - вероятность вхождения слова $x_i$ d документ класса Q определяется как:
#
# $$P(x_i|Q_y) = \frac{N_{iy} + \alpha}{N_y + \alpha n}$$
#
# где
# * $N_k$ - количества слов входящий в документ класса Q
# * $N_{ik}$ - количество вхождений слова x_{i} в документ класса $Q$
# * $\alpha$ - параметр сглаживания [0, 1)
# * $n$ - количество слов из обучающей выборки
#
# Второй параметр формулы наивного Байеса: $P(Q_i) = \frac{N_{Qy}}{N}$
# где
# * $N_{y}$ - количество документов класса y
# * $N$ - все количество документов
#
# Итого получаем:
#
# $$arg\max[P(Q_y)\prod_{i=1}^nP(x_i|Q_y)]$$
#
# Переходя к логарифмам:
#
# $$arg\max[\log{P(Q_y)}+\sum_{i=1}^n\log{P(x_i|Q_y)}]$$

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Используем оптимизированный в sklearn на примере русских твиттов

# %% [markdown]
# Данные взяты из статьи http://www.swsys.ru/index.php?page=article&id=3962&lang=
#
# В корпусе 114,911 положительных и 111,923 отрицательных записей. Представляют из себя разметку сентимента русскоязычных твитов. (сорс https://study.mokoron.com/ там есть и на 17 миллионов значений, кто хочет взять нечто подобное для проекта)

# %%
neg = pd.read_csv('https://raw.githubusercontent.com/tixonsit/mmdad_materials/master/negative.csv', encoding='utf8', sep=';', header=None)

# %%
pos = pd.read_csv('https://raw.githubusercontent.com/tixonsit/mmdad_materials/master/positive.csv', encoding='utf8', sep=';', header=None)

# %%
pos[3]
# Out:
# 0         @first_timee хоть я и школота, но поверь, у на...
# 1         Да, все-таки он немного похож на него. Но мой ...
# 2         RT @KatiaCheh: Ну ты идиотка) я испугалась за ...
# 3         RT @digger2912: "Кто то в углу сидит и погибае...
# 4         @irina_dyshkant Вот что значит страшилка :D\nН...
#                                 ...
# 114906    Спала в родительском доме, на своей кровати......
# 114907    RT @jebesilofyt: Эх... Мы немного решили сокра...
# 114908    Что происходит со мной, когда в эфире #proacti...
# 114909    "Любимая,я подарю тебе эту звезду..." Имя како...
# 114910    @Ma_che_rie посмотри #непытайтесьпокинутьомск ...
# Name: 3, Length: 114911, dtype: object

# %%
neg[3]
# Out:
# 0         на работе был полный пиддес :| и так каждое за...
# 1         Коллеги сидят рубятся в Urban terror, а я из-з...
# 2         @elina_4post как говорят обещаного три года жд...
# 3         Желаю хорошего полёта и удачной посадки,я буду...
# 4         Обновил за каким-то лешим surf, теперь не рабо...
#                                 ...
# 111918    Но не каждый хочет что то исправлять:( http://...
# 111919    скучаю так :-( только @taaannyaaa вправляет мо...
# 111920            Вот и в школу, в говно это идти уже надо(
# 111921    RT @_Them__: @LisaBeroud Тауриэль, не грусти :...
# 111922    Такси везет меня на работу. Раздумываю приплат...
# Name: 3, Length: 111923, dtype: object

# %%
df = pos.append(neg, ignore_index = True)
df = df.sample(frac=1).reset_index(drop=True)
len(df)
# Out:
# 226834

# %%
df.head()
# Out:
#                    0           1                2   \
# 0  411903198010810368  1387040349      jofurecikom
# 1  409917856156254208  1386567007     alenka_87_08
# 2  409763289644933121  1386530155        oshkova95
# 3  410066152115937281  1386602363  danjawaliyllina
# 4  410475283993464832  1386699908      BetsiMorgan
#
#                                                   3   4   5   6   7      8   \
# 0  RT @zacapidobibu: ну вот :( почитал жуйк и оде...  -1   0   1   0   1087
# 1  Возбуждено уголовное дело за снос памятника Ле...  -1   0   0   0     76
# 2  RT @oleg_lebedev253: Трудно, когда знаешь прав...   1   0   1   0   1529
# 3  @Olga100764 Ха ха добрый,а кому-то особенно! :...   1   0   0   0   4977
# 4  #ХочуПровестиНовогоднююНочьВместеС\nа со мной ...   1   0   0   0  12428
#
#     9    10  11
# 0  246  268   0
# 1   75   75   0
# 2   24   21   0
# 3  715  706  21
# 4  690  674   3

# %%
# сделаем привычные 1, 0
df[4] = df[4].map({-1:0, 1:1})
df.head()
# Out:
#                    0           1                2   \
# 0  411903198010810368  1387040349      jofurecikom
# 1  409917856156254208  1386567007     alenka_87_08
# 2  409763289644933121  1386530155        oshkova95
# 3  410066152115937281  1386602363  danjawaliyllina
# 4  410475283993464832  1386699908      BetsiMorgan
#
#                                                   3   4   5   6   7      8   \
# 0  RT @zacapidobibu: ну вот :( почитал жуйк и оде...   0   0   1   0   1087
# 1  Возбуждено уголовное дело за снос памятника Ле...   0   0   0   0     76
# 2  RT @oleg_lebedev253: Трудно, когда знаешь прав...   1   0   1   0   1529
# 3  @Olga100764 Ха ха добрый,а кому-то особенно! :...   1   0   0   0   4977
# 4  #ХочуПровестиНовогоднююНочьВместеС\nа со мной ...   1   0   0   0  12428
#
#     9    10  11
# 0  246  268   0
# 1   75   75   0
# 2   24   21   0
# 3  715  706  21
# 4  690  674   3

# %%
df[4].value_counts()
# Out:
# 1    114911
# 0    111923
# Name: 4, dtype: int64

# %% [markdown]
# ## Кодирования текста

# %% [markdown]
# ### 1.Векторное представление текста (One Hot Vectorizer)

# %% [markdown]
# Представим текст как вектор индикаторов вхождений слов из некоторого словаря в текст. Простейшая модель BOF (Bag of words или мешок слов).

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(binary=True) # бинарное представление подсчета (0 - не входит, 1 - входит)
vectorizer.fit(df[3])
# Out:
# CountVectorizer(binary=True)

# %%
len(vectorizer.vocabulary_)
# Out:
# 294600

# %% [markdown]
# ### Train-test split

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2, shuffle=True)

# %%
df_train.shape, df_test.shape
# Out:
# ((181467, 12), (45367, 12))

# %%
X_train = vectorizer.transform(df_train[3])
X_test = vectorizer.transform(df_test[3])

# %%
X_train.shape, X_test.shape
# Out:
# ((181467, 294600), (45367, 294600))

# %% [markdown]
# #### Алгоритм

# %%
clf = MultinomialNB().fit(X_train, df_train[4])

# %%
# выбрать n лучших (по вероятностям) слов для каждого класса
def show_top(classifier, vectorizer, n, categories=('pos', 'neg')):
    # получаем слова
    feature_names = np.asarray(vectorizer.get_feature_names())
    # проходимлся по словам
    for i, category in enumerate(categories):
        # выбираем лучшие по вероятностям
        top = np.argsort(classifier.feature_log_prob_[i])[-n:]
        print("%s: %s" % (category, " ".join(feature_names[top])))

# отобразим 20 топовых слов
show_top(clf, vectorizer, 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# pos: же за ты по уже ну это все но то мне так co http как меня rt на что не
# neg: вот да за по ну но все мне так меня ты то это как что на rt co http не

# %% [markdown]
# #### Оценка

# %%
from sklearn.metrics import classification_report

predicts = clf.predict(X_train)
# train
print(classification_report(df_train[4], predicts, target_names=['Негативные', 'Позитивные']))
# Out:
#               precision    recall  f1-score   support
#
#   Негативные       0.87      0.93      0.90     89594
#   Позитивные       0.92      0.86      0.89     91873
#
#     accuracy                           0.89    181467
#    macro avg       0.90      0.89      0.89    181467
# weighted avg       0.90      0.89      0.89    181467

# %%
predicts = clf.predict(X_test)
print(classification_report(df_test[4], predicts, target_names=['Негативные', 'Позитивные']))
# Out:
#               precision    recall  f1-score   support
#
#   Негативные       0.73      0.80      0.77     22329
#   Позитивные       0.79      0.72      0.75     23038
#
#     accuracy                           0.76     45367
#    macro avg       0.76      0.76      0.76     45367
# weighted avg       0.76      0.76      0.76     45367

# %% [markdown]
# ### 2.Bag of words (CountVectorizer)

# %% [markdown]
# При построении вектора признаков будем учитывать не просто факт вхождения слова в текст, а подсчитывать количество вхождений:

# %%
count_vect = CountVectorizer(binary=False).fit(df[3])

X_train_counts = count_vect.transform(df_train[3])
X_test_counts = count_vect.transform(df_test[3])

# %% [markdown]
# Для примера выведем слова вместе и количеством вхождений для обучающего датасета:

# %%
# представление 42го отзыва
dict(zip(count_vect.inverse_transform(X_train_counts[199])[0], X_train_counts[0].data))
# Out:
# {'выступал': 1,
#  'ипр': 1,
#  'который': 1,
#  'курса': 1,
#  'курсами': 1,
#  'мальчик': 1,
#  'на': 1,
#  'отзовиииииись': 1,
#  'первого': 1,
#  'посвяте': 1,
#  'сам': 2,
#  'сегодня': 1,
#  'со': 1,
#  'старшими': 1}

# %% [markdown]
# #### Алгоритм

# %% [markdown]
# #### С часто встреч словами

# %%
# обучим
clf = MultinomialNB().fit(X_train_counts, df_train[4])

# %%
# train
predicts = clf.predict(X_train_counts)
print(classification_report(df_train[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89     89594
#            1       0.92      0.86      0.89     91873
#
#     accuracy                           0.89    181467
#    macro avg       0.89      0.89      0.89    181467
# weighted avg       0.89      0.89      0.89    181467

# %%
# test
# конвертируем тестовые слова
predicts = clf.predict(count_vect.transform(df_test[3]))
print(classification_report(df_test[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.77     22329
#            1       0.79      0.72      0.75     23038
#
#     accuracy                           0.76     45367
#    macro avg       0.76      0.76      0.76     45367
# weighted avg       0.76      0.76      0.76     45367

# %%
show_top(clf, vectorizer, 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# pos: хочу за уже ты по ну это все но мне так http co то как меня rt на что не
# neg: вот да за по ну но мне все так меня ты то это как что на rt co http не

# %% [markdown]
# #### Пробуем убрать часто встречающиеся слова

# %%
'''
в англ:

from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS

count_vect = CountVectorizer(stop_words=ENGLISH_STOP_WORDS, binary=False).fit(df[3])
'''
# !pip install --user -U nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
from nltk.corpus import stopwords
stopWords = stopwords.words('russian')
stopWords
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
count_vect = CountVectorizer(stop_words=stopWords[:20], binary=False).fit(df[3])

# %%
X_train_counts = count_vect.transform(df_train[3])
X_test_counts = count_vect.transform(df_test[3])

# %%
clf = MultinomialNB().fit(X_train_counts, df_train[4])

# %%
predicts = clf.predict(X_test_counts)
print(classification_report(df_test[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76     22329
#            1       0.78      0.73      0.75     23038
#
#     accuracy                           0.76     45367
#    macro avg       0.76      0.76      0.76     45367
# weighted avg       0.76      0.76      0.76     45367

# %%
show_top(clf, count_vect, 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# pos: очень бы сегодня когда еще только нет вот же хочу за уже по ну это мне http co меня rt
# neg: просто тебе мы бы еще только же тебя сегодня уже вот за по ну мне меня это rt co http

# %% [markdown]
# ### 3.TF-IDF

# %% [markdown]
# #### 3.1.Простой

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words=stopWords[:20])
vectorizer = vectorizer.fit(df[3])

# %%
X_train_vectors = vectorizer.transform(df_train[3])
X_test_vectors = vectorizer.transform(df_test[3])

# %%
num = 65
X_train_vectors[num].data
# Out:
# array([0.24492741, 0.20117187, 0.14353639, 0.21397604, 0.37714313,
#        0.2528097 , 0.17154231, 0.11588339, 0.37714313, 0.33226141,
#        0.15453044, 0.24675866, 0.14483557, 0.32911745, 0.0839596 ,
#        0.33226141])

# %% [markdown]
# Выведем слова из первого документа в порядке увеличения из меры TF-IDF:

# %%
vectorizer.inverse_transform(X_train_vectors[num])[0][np.argsort(X_train_vectors[num].data)]
# Out:
# array(['rt', 'ну', 'там', 'вообще', 'знаю', 'один', 'твит', 'счастья',
#        'фиг', 'здоровья', 'поздравления', 'stringi_konya', 'ихиххи',
#        'bllack_parade', 'поместишь', 'коняного'], dtype='<U136')

# %% [markdown]
# ##### Алгоритм

# %%
clf = MultinomialNB().fit(X_train_vectors, df_train[4])

# %%
show_top(clf, vectorizer, 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# pos: бы очень когда сегодня еще только вот за же по нет ну уже хочу это http co мне rt меня
# neg: еще мы только же бы тебе спасибо уже сегодня тебя вот за по ну мне меня это rt http co

# %%
predicts = clf.predict(vectorizer.transform(df_test[3]))
print(classification_report(df_test[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76     22329
#            1       0.78      0.73      0.75     23038
#
#     accuracy                           0.76     45367
#    macro avg       0.76      0.76      0.76     45367
# weighted avg       0.76      0.76      0.76     45367

# %% [markdown]
# #### 3.2.TF-IDF + пары слов (n-grams)
#
# Попробуем подсчитывать не только одиночные слова, но и пары слов:

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 3)).fit(df[3])

X_train_vectors = vectorizer.transform(df_train[3])
X_test_vectors = vectorizer.transform(df_test[3])

# %% [markdown]
# Выведем слова из первого документа в порядке увеличения из меры TF-IDF:

# %%
vectorizer.inverse_transform(X_train_vectors[num])[0][np.argsort(X_train_vectors[num].data)]
# Out:
# array(['не', 'rt', 'ну', 'там', 'вообще', 'знаю', 'не знаю', 'один',
#        'твит', 'счастья', 'ну не', 'фиг', 'здоровья', 'поздравления',
#        'ну не знаю', 'счастья здоровья', 'там ну', 'stringi_konya',
#        'вообще один', 'ихиххи', 'bllack_parade', 'один твит',
#        'rt stringi_konya', 'там ну не', 'один твит фиг',
#        'bllack_parade ихиххи вообще', 'фиг поместишь',
#        'rt stringi_konya bllack_parade', 'твит фиг поместишь',
#        'stringi_konya bllack_parade',
#        'stringi_konya bllack_parade ихиххи', 'твит фиг',
#        'вообще один твит', 'счастья здоровья коняного',
#        'здоровья коняного', 'поместишь поздравления счастья',
#        'поместишь поздравления', 'ихиххи вообще', 'ихиххи вообще один',
#        'коняного', 'коняного там', 'коняного там ну', 'поместишь',
#        'поздравления счастья здоровья', 'bllack_parade ихиххи',
#        'поздравления счастья', 'здоровья коняного там',
#        'фиг поместишь поздравления'], dtype='<U137')

# %% [markdown]
# ##### Алгоритм

# %%
clf = MultinomialNB(alpha = 1).fit(X_train_vectors, df_train[4])

# %%
predicts = clf.predict(vectorizer.transform(df_test[3]))
print(classification_report(df_test[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78     22329
#            1       0.81      0.73      0.77     23038
#
#     accuracy                           0.77     45367
#    macro avg       0.78      0.77      0.77     45367
# weighted avg       0.78      0.77      0.77     45367

# %% [markdown]
# # 3.Complement Naive Bayes

# %% [markdown]
# Наивный байесовский классификатор ComplementNB был разработан для исправления «грубых допущений», сделанных стандартным полиномиальным наивным байесовским классификатором. Хорошо работает с несбалансированным набором данных.
#
# CNB - это адаптация стандартного полиномиального наивного байесовского алгоритма (MNB), который особенно подходит для несбалансированных наборов данных. В частности, CNB использует статистику из дополнения каждого класса для вычисления весов модели. Изобретатели CNB эмпирически показывают, что оценки параметров для CNB более стабильны, чем оценки для MNB. Кроме того, CNB регулярно опережает MNB (часто со значительным отрывом) по задачам классификации текста. Процедура расчета весов выглядит следующим образом:
#
# \begin{align}\begin{aligned}\hat{\theta}_{ci} = \frac{\alpha_i + \sum_{j:y_j \neq c} d_{ij}}
#                          {\alpha + \sum_{j:y_j \neq c} \sum_{k} d_{kj}}\\w_{ci} = \log \hat{\theta}_{ci}\\w_{ci} = \frac{w_{ci}}{\sum_{j} |w_{cj}|}\end{aligned}\end{align}

# %% [markdown]
# где суммирования по всем документам j, не относящимся к классу С, $d_{ij}$ - это значение tf-idf термина i в документе j, $αi$ - это сглаживающий гиперпараметр, подобный найденному в MNB, и $α = ∑_i αi$. Вторая нормализация учитывает тенденцию для более длинных документов доминировать в оценках параметров в MNB. Правило классификации:

# %% [markdown]
# $$\hat{c} = \arg\min_c \sum_{i} t_i w_{ci}$$

# %% [markdown]
# то есть документ присваивается классу, который является самым плохим соответствием дополнения.

# %% [markdown]
# Простыми словами:
#
# Сравнивая с классическим наивным байесовским алгоритмом, вместо вычисления вероятности появления слова в классе, мы вычисляем вероятность того, что оно встречается в других классах.

# %% [markdown]
# Классический:
# $$argmax \ p(y) \bullet \prod p(w | y)^{f_i}$$
# Преобразуется в:
# $$argmin \ p(y) \bullet \prod {1 \over p(w | \hat y)^{f_i}}$$
#
# где $f_i$ - частота слова i документа d

# %% [markdown]
# Проверим предположение с помощью tfidf + пары слов и стоп слов для русского.

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 3)).fit(df[3])

X_train_vectors = vectorizer.transform(df_train[3])
X_test_vectors = vectorizer.transform(df_test[3])

# %%
X_train_vectors = vectorizer.transform(df_train[3])
X_test_vectors = vectorizer.transform(df_test[3])

# %%
vectorizer.inverse_transform(X_train_vectors[num])[0][np.argsort(X_train_vectors[num].data)]
# Out:
# array(['не', 'на', 'что', 'так', 'все', 'было', 'надо', 'хорошо', 'пока',
#        'видео', 'сказали', 'пока не', 'сказали что', 'сайт', 'было так',
#        'так хорошо', 'все было', 'выкладывать', 'на сайт', 'не сказали',
#        'было так хорошо', 'хорошо пока', 'все было так', 'не сказали что',
#        'хорошо пока не', 'что видео', 'надо выкладывать',
#        'пока не сказали', 'сказали что видео', 'выкладывать на сайт',
#        'выкладывать на', 'так хорошо пока', 'видео надо выкладывать',
#        'видео надо', 'надо выкладывать на', 'что видео надо'],
#       dtype='<U137')

# %% [markdown]
# ##  Алгоритм

# %%
from sklearn.naive_bayes import ComplementNB
clf = ComplementNB()
clf.fit(X_train_vectors, df_train[4])
# Out:
# ComplementNB(alpha=1.0, class_prior=None, fit_prior=True, norm=False)

# %%
predicts = clf.predict(vectorizer.transform(df_test[3]))
print(classification_report(df_test[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.83      0.78     22517
#            1       0.81      0.71      0.75     22850
#
#     accuracy                           0.77     45367
#    macro avg       0.77      0.77      0.77     45367
# weighted avg       0.77      0.77      0.77     45367

# %% [markdown]
# # 4.Bernoulli Naive Bayes

# %% [markdown]
# ## Алгоритм

# %%
clf = BernoulliNB(alpha=0.5).fit(X_train_vectors, df_train[4])

# %%
show_top(clf, vectorizer, 20)
# Out:
# pos: ты за по уже ну это все но то так мне http co co http как меня rt на что не
# neg: да за по ну но все мне так ты меня то это как что на rt http co co http не

# %%
predicts = clf.predict(vectorizer.transform(df_test[3]))
print(classification_report(df_test[4], predicts))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.88      0.78     22517
#            1       0.84      0.62      0.71     22850
#
#     accuracy                           0.75     45367
#    macro avg       0.77      0.75      0.74     45367
# weighted avg       0.77      0.75      0.74     45367

# %% [markdown]
# ## GridSearch for BernoulliNB

# %%
# ComplementNB, MultinomialNB, BernoulliNB, CategoricalNB

from sklearn.model_selection import GridSearchCV

alg = BernoulliNB()

grid = {'alpha': np.array(np.linspace(0, 6, 30), dtype='float'),}

gs = GridSearchCV(alg, grid, verbose=2, n_jobs = -1, scoring = 'f1')
gs.fit(X_train_vectors, df_train[4])
gs.best_params_, gs.best_score_
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   42.9s finished
# ({'alpha': 4.9655172413793105}, 0.7657067839707224)

# %%
# Функция отрисовки графиков
def grid_plot(x, y, x_label, title, y_label='f1'):
    # определили размер графика
    plt.figure(figsize=(12, 6))
    # добавили сетку на фон
    plt.grid(True)
    # построили по х - число соседей, по y - точность
    plt.plot(x, y, 'go-')
    # добавили подписи осей и название графика
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

# %%
# Строим график зависимости качества от числа соседей
# замечание: результаты обучения хранятся в атрибуте cv_results_ объекта gs
grid_plot(grid['alpha'], gs.cv_results_['mean_test_score'], 'n_neighbors', 'BernoulliNB')

# %% [markdown]
# ## Фильтруем самые частотные

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
freq = get_top_n_words(df_test[3], 50)

# %%
freq = [i[0] for i in freq]

# %%
vectorizer = TfidfVectorizer(stop_words=stopWords+freq+list(ENGLISH_STOP_WORDS), ngram_range=(1, 2)).fit(df[3])

X_train_vectors = vectorizer.transform(df_train[3])
X_test_vectors = vectorizer.transform(df_test[3])

# %%
clf = BernoulliNB(alpha=0.5).fit(X_train_vectors, df_train[4])

# %%
show_top(clf, vectorizer, 20)
# Out:
# pos: бля такое болит о_о время люблю новый жаль плохо хочется год делать дома спать знаю буду вообще почему могу блин
# neg: нам такая такие утро могу год почему дома dd новый ахаха время пока ахах знаю вообще буду всем люблю спасибо

# %%
# ComplementNB, MultinomialNB, BernoulliNB, CategoricalNB

from sklearn.model_selection import GridSearchCV

alg = BernoulliNB()

grid = {'alpha': np.array(np.linspace(0, 6, 30), dtype='float'),}

gs = GridSearchCV(alg, grid, verbose=2, n_jobs = -1, scoring = 'f1')
gs.fit(X_train_vectors, df_train[4])
gs.best_params_, gs.best_score_
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   37.6s finished
# ({'alpha': 2.689655172413793}, 0.7613353634780609)

# %%
# Строим график зависимости качества от числа соседей
# замечание: результаты обучения хранятся в атрибуте cv_results_ объекта gs
grid_plot(grid['alpha'], gs.cv_results_['mean_test_score'], 'n_neighbors', 'BernoulliNB')

# %%
stopWords
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
from nltk.stem.snowball import SnowballStemmer
stem = SnowballStemmer("russian")

# %%
from tqdm import tqdm

for i in tqdm(range(20))

# %%
def preprocess(doc):
    doc = doc.split()
    doc = [stem.stem(word) for word in doc]
    doc = ' '.join(doc)
    return doc

df[3] = df[3].map(preprocess)

# %%
df
# Out:
#                         0           1                2   ...   9    10  11
# 0       413662489831018496  1387459797  rachel___rachel  ...  674  276  19
# 1       410080544652005376  1386605795  Natali_Gortseva  ...   49   42   0
# 2       410865067161571328  1386792840      lolotrololo  ...  378   94  29
# 3       409088152503336961  1386369190    aliinamalinaa  ...  116   56   0
# 4       424875442051776512  1390133173  KarinaBalashova  ...   36   37   1
# ...                    ...         ...              ...  ...  ...  ...  ..
# 226829  410047082888978432  1386597817  ___lermaniac___  ...  537  422   6
# 226830  409425297759408128  1386449572       rinata_sha  ...   69   83   0
# 226831  415187764464742400  1387823451   IrinaSuslonova  ...   25   12   0
# 226832  410780245068115969  1386772617         jullyrob  ...  145  115   3
# 226833  408925443870310401  1386330397       nastia_fap  ...   42   30   0
#
# [226834 rows x 12 columns]
